# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from funciones import *

# %%
K = 10**5
n = 1

# %% [markdown]
# # $\mu = 10^{-4}$

# %%
mu = 10**-4
delta1 = np.log(K)/(mu+np.sqrt(2*K*mu))
print(delta1)
# Out:
# 2.574310832616011

# %% [markdown]
# ## $\Delta = 10^{-3}\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = delta1/1000

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 10^-3Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 10^-3Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 10^{-2}\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = delta1/100

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 10^-2Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 10^-2Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 10^{-1}\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = delta1/10

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 10^-1Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 10^-1Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = \Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = delta1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 10^{5/2}\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = (10**(5/2))*delta1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 10^52Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 10^52Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 10^3\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 1000*delta1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 10^3Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 10^3Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# # $\mu = 10^{2}$

# %%
mu = 10**2
K = 10**5
delta1 = np.log(K)/(mu+np.sqrt(2*K*mu))
print(delta1)
# Out:
# 0.002518062800031345

# %% [markdown]
# ## $\Delta = \Delta_1^*/2$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = delta1/2

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 0.5Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 0.5Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = \Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = delta1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 3\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 3*delta1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 3Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 3Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 5\Delta_1^*$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 5*delta1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes 5Delta1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times 5Delta1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# # $\mu = 1$ $n=0$

# %%
mu = 10
n = 0
K = 10**5
delta1 = np.log(K)/(mu+np.sqrt(2*K*mu))
print(delta1)
# Out:
# 0.008083707225612163

# %% [markdown]
# ## $\Delta = 15$
#
# ### Post transición

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 15

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=15 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=15 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()
# Out:
# C:\Users\anton\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\lib\histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## $\Delta = 10$
#
# ### Al terminar transición

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 10

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=10 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=10 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 5$
#
# ### Empezar transición

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 5

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=5 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=5 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 1$
#
# ### Justo antes de la transición

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 1

for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 1.5
for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=1 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=1 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()
# Out:
# C:\Users\anton\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\lib\histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## $\Delta =2$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 2
for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=2 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=2 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 2$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 2
for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=2 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=2 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# ## $\Delta = 2.5$

# %%
R = 10**3
all_cluster_sizes = []
all_cluster_times = []
delta = 2.5
for _ in range(R):
    times, _ = generate_series(K, n, mu)
    _, cluster_sizes, cluster_times = identify_clusters_model(times, delta)
    all_cluster_sizes.extend(cluster_sizes)
    all_cluster_times.extend(cluster_times)
np.save(f'./data/Sizes Delta=2.5 mu={mu}', all_cluster_sizes)
np.save(f'./data/Times Delta=2.5 mu={mu}', all_cluster_times)

s_bins = np.logspace(0, 5, num = 50, base = 10)
t_bins = np.logspace(-4, 2, num = 50, base = 10)
y_s = s_bins**(-2)
y_t = t_bins**(-2)*10**-5
y_s2 = s_bins**(-3/2)

fig = plt.figure(figsize=(10, 5))
axgrid = fig.add_gridspec(1,2)
ax0 = fig.add_subplot(axgrid[0,0])
ax1 = fig.add_subplot(axgrid[0,1])

s_hist = np.histogram(all_cluster_sizes, bins=s_bins, density = True)
ax0.scatter(s_bins[:-1], s_hist[0])
ax0.plot(s_bins, y_s, label='$S^{-2}$')
ax0.plot(s_bins, y_s2, label='$S^{-3/2}$')
ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.legend()
ax0.set_xlabel('Cluster size $S$')
ax0.set_ylabel('Probability distribution')

t_hist = np.histogram(all_cluster_times, bins=t_bins, density = True)
ax1.scatter(t_bins[:-1], t_hist[0])
ax1.plot(t_bins[10:], y_t[10:], label='$T^{-2}$')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Cluster duration $T$')
ax1.set_ylabel('Probability distribution')
ax1.legend()

fig.suptitle(f'$\Delta=${delta:.1E} and ${R}$ iterations', fontsize=20)

fig.tight_layout()

# %% [markdown]
# # Susceptibility $\chi$

# %% [markdown]
# ## n=1

# %%
fig = plt.figure(figsize=(12, 4))
axgrid = fig.add_gridspec(1, 3)

R = 10**3
mus = [1, 10**-4, 10**2]
ns = [0, 1, 1]

labels = ['$K=10^3$', '$K=10^4$','$K=10^5$','$K=10^6$','$K=10^7$','$K=10^8$']
deltas = [np.logspace(-1, 2, num = 100, base = 10), np.logspace(-4, 6, num = 100, base = 10), np.logspace(-4, 0, num = 100, base = 10)]
np.save (f'./data/deltas_R={R}_article_susceptibility_n=1', deltas)

for i in range(3):
    n = ns[i]
    mu = mus[i]
    ax = fig.add_subplot(axgrid[0, i])
    for _ in range(3):
        K = 10**(_+3) 
        delta = deltas[i]
        percolations = np.zeros([R, len(delta)])
        
        for j in range(R):
            times_between_events, _, _ = generate_series_perc(K, n, mu)
            percolations[j,:] = calculate_percolation_strength(times_between_events, delta)

        numerator = np.std(percolations, axis=0)**2
        denominator = np.mean(percolations, axis=0)
        susceptibility = numerator/denominator
        np.save(f'./data/percolation_susceptibility_n=1_mu={mu}_K={K},R={R}', susceptibility)
        ax.plot(delta, susceptibility, marker='o', markersize=5)

    ax.set_xscale('log')

fig.supxlabel('Resolution parameter $\Delta$', fontsize=16)
fig.axes[0].set_title('$n=0$, $\mu=1$', fontsize=11)
fig.axes[1].set_title('$n=1$, $\mu=10^{-4}$', fontsize=11)
fig.axes[2].set_title('$n=1$, $\mu=10^{2}$', fontsize=11)
fig.axes[0].legend(labels, loc='upper left', ncol=1, fontsize=11)
fig.supylabel('Susceptibility $\chi$', fontsize=16)

fig.tight_layout()

# %% [markdown]
# ## n=2

# %%
fig = plt.figure(figsize=(12, 4))
axgrid = fig.add_gridspec(1, 3)

R = 10**3
mus = [1, 10**-4, 10**2]
ns = [0, 2, 2]

labels = ['$K=10^3$', '$K=10^4$','$K=10^5$','$K=10^6$','$K=10^7$','$K=10^8$']
deltas = [np.logspace(-1, 2, num = 100, base = 10), np.logspace(-6, 2, num = 100, base = 10), np.logspace(-5, 0, num = 100, base = 10)]
np.save (f'./data/deltas_R={R}_n=2', deltas)

for i in range(3):
    n = ns[i]
    mu = mus[i]
    ax = fig.add_subplot(axgrid[0, i])
    for _ in range(3):
        K = 10**(_+3) 
        delta = deltas[i]
        percolations = np.zeros([R, len(delta)])
        
        for j in range(R):
            times_between_events, _, _ = generate_series_perc(K, n, mu)
            percolations[j,:] = calculate_percolation_strength(times_between_events, delta)

        susceptibility = np.std(percolations, axis=0)**2/np.mean(percolations, axis=0)
        ax.plot(delta, susceptibility, marker='o', markersize=5)

    ax.set_xscale('log')

fig.supxlabel('Resolution parameter $\Delta$', fontsize=16)
fig.axes[0].set_title('$n=0$, $\mu=1$', fontsize=11)
fig.axes[1].set_title('$n=2$, $\mu=10^{-4}$', fontsize=11)
fig.axes[2].set_title('$n=2$, $\mu=10^{2}$', fontsize=11)
fig.axes[0].legend(labels, loc='upper left', ncol=1, fontsize=11)
fig.supylabel('Susceptibility $\chi$', fontsize=16)

fig.tight_layout()

# %%
K = 10**4
mu1 = 10**-4
mu2 = 10**-4

nEE = 1.5#0.96
nEI = 1#0.24
nIE = -1 #-0.3
nII = 0. #0./10

# %%
times_between_events, times, rate1, rate2, reactions = generate_series_bivariate(K, nEE, nII, nEI, nIE, mu1, mu2)
plt.figure(figsize=(15,5))
plt.plot(times, rate1, label='$\lambda_E$')
plt.plot(times, rate2, label='$\lambda_I$')
plt.axhline(y=mu1, color='r', linestyle='--', label='$\mu_E$')
#plt.axhline(y=0, color='g', linestyle='--', label='$\lambda=0$')
plt.xlabel('Time')
#plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Rate $\lambda$')
plt.legend()
plt.tight_layout()

# %%
mus1 = [1, 10**-4, 10**2]
mus2 = [1, 10**-4, 10**2]

R = 10**3

labels = ['K=$10^{3}$', 'K=$10^{4}$', 'K=$10^{5}$']
deltas = [np.logspace(-1, 2, 100), np.logspace(-5, 1, 100), np.logspace(-4.5, -1, 100)]
np.save(f'./data/deltas_bivariate_stationary', deltas)
ns11 = [0, nEE, nEE]
ns22 = [0, nII, nII]
ns12 = [0, nEI, nEI]
ns21 = [0, nIE, nIE]

fig = plt.figure(figsize=(12, 4))
axgrid = fig.add_gridspec(1, 3)

for i in range(len(mus1)):
    n11 = ns11[i]
    n12 = ns12[i]
    n21 = ns21[i]
    n22 = ns22[i]
    mu1 = mus1[i]
    mu2 = mus2[i]
    ax = fig.add_subplot(axgrid[0, i])
    for _ in range(3):
        K = 10**(_+3)
        delta = deltas[i]
        percolations = np.zeros([R, len(delta)])
        for j in range(R):
            times_between_events, _, _, _, _ = generate_series_bivariate(K, n11, n12, n21, n22, mu1, mu2)
            percolations[j, :] = calculate_percolation_strength(times_between_events, delta)

        percolation_mean = np.mean(percolations, axis=0)
        percolation_sus = np.std(percolations, axis=0)**2/percolation_mean #susceptibility
        
        np.save(f'./data/percolation_mean_bivariate_stationary_plot_{i}_K={K}', percolation_mean)
        np.save(f'./data/percolation_sus_bivariate_stationary_plot_{i}_K={K}', percolation_sus)

        ax.plot(delta, percolation_mean, marker = 'o')
        #ax.plot(delta, percolation_sus, marker = 'o')

    ax.set_xscale('log')
    ax.set_ylim(0, 1.1)  
    ax.set_yticks([0, 0.5, 1])


fig.axes[0].set_title(f'$\mu_E=10^{ int(np.log10(mus1[0]))}$, $\mu_I=10^{ int(np.log10(mus2[0]))}$, $n_{{EE}}=${ns11[0]}, $n_{{II}}=${ns22[0]}, $n_{{EI}}=${ns12[0]}, $n_{{IE}}=${ns21[0]}', fontsize = 8)
fig.axes[1].set_title(f'$\mu_E=10^{ {int(np.log10(mus1[1]))}}$, $\mu_I=10^{ {int(np.log10(mus2[1]))}}$, $n_{{EE}}=${ns11[1]}, $n_{{II}}=${ns22[1]}, $n_{{EI}}=${ns12[1]}, $n_{{IE}}=${ns21[1]}', fontsize = 8)
fig.axes[2].set_title(f'$\mu_E=10^{ {int(np.log10(mus1[2]))}}$, $\mu_I=10^{ {int(np.log10(mus2[2]))}}$, $n_{{EE}}=${ns11[2]}, $n_{{II}}=${ns22[2]}, $n_{{EI}}=${ns12[2]}, $n_{{IE}}=${ns21[2]}', fontsize = 8)

fig.supxlabel('Resolution parameter $\Delta$', fontsize=16)
fig.axes[0].minorticks_off()
fig.axes[2].minorticks_off()
fig.axes[0].legend(labels, loc='best', ncol=1)
fig.supylabel('Percolation strength $P_{\infty}$', fontsize=16)
fig.tight_layout()

# %% [markdown]
# # Double transition parameters

# %%
K = 10**4
mu1 = 10**-4
mu2 = 10**-4

nEE = 0.96
nEI = 0.24
nIE = -0.3
nII = 0./10

# %%
times_between_events, times, rate1, rate2, reactions = generate_series_bivariate(K, nEE, nII, nEI, nIE, mu1, mu2)
plt.figure(figsize=(15,5))
plt.plot(times, rate1, label='$\lambda_E$')
plt.plot(times, rate2, label='$\lambda_I$')
plt.axhline(y=mu1, color='r', linestyle='--', label='$\mu_E$')
#plt.axhline(y=0, color='g', linestyle='--', label='$\lambda=0$')
plt.xlabel('Time')
#plt.yscale('log')
#plt.xscale('log')
plt.ylabel('Rate $\lambda$')
plt.legend()
plt.tight_layout()

# %%
mus1 = [1, 10**-4, 10**2]
mus2 = [1, 10**-4, 10**2]

R = 10**3

labels = ['K=$10^{3}$', 'K=$10^{4}$', 'K=$10^{5}$']
deltas = [np.logspace(-1, 2, 100), np.logspace(-2, 6, 100), np.logspace(-3, -1, 100)]
np.save(f'./data/deltas_bivariate_PRL', deltas)
ns11 = [0, nEE, nEE]
ns22 = [0, nII, nII]
ns12 = [0, nEI, nEI]
ns21 = [0, nIE, nIE]

fig = plt.figure(figsize=(12, 4))
axgrid = fig.add_gridspec(1, 3)

for i in range(len(mus1)):
    n11 = ns11[i]
    n12 = ns12[i]
    n21 = ns21[i]
    n22 = ns22[i]
    mu1 = mus1[i]
    mu2 = mus2[i]
    ax = fig.add_subplot(axgrid[0, i])
    for _ in range(3):
        K = 10**(_+3)
        delta = deltas[i]
        percolations = np.zeros([R, len(delta)])
        for j in range(R):
            times_between_events, _, _, _, _ = generate_series_bivariate(K, n11, n12, n21, n22, mu1, mu2)
            percolations[j, :] = calculate_percolation_strength(times_between_events, delta)

        percolation_mean = np.mean(percolations, axis=0)
        percolation_sus = np.std(percolations, axis=0)**2/percolation_mean #susceptibility
        
        np.save(f'./data/percolation_mean_bivariate_PRL_plot_{i}_K={K}', percolation_mean)
        np.save(f'./data/percolation_sus_bivariate_PRL_plot_{i}_K={K}', percolation_sus)

        ax.plot(delta, percolation_mean, marker = 'o')
        #ax.plot(delta, percolation_sus, marker = 'o')

    ax.set_xscale('log')
    ax.set_ylim(0, 1.1)  
    ax.set_yticks([0, 0.5, 1])


fig.axes[0].set_title(f'$\mu_E=10^{ int(np.log10(mus1[0]))}$, $\mu_I=10^{ int(np.log10(mus2[0]))}$, $n_{{EE}}=${ns11[0]}, $n_{{II}}=${ns22[0]}, $n_{{EI}}=${ns12[0]}, $n_{{IE}}=${ns21[0]}', fontsize = 8)
fig.axes[1].set_title(f'$\mu_E=10^{ {int(np.log10(mus1[1]))}}$, $\mu_I=10^{ {int(np.log10(mus2[1]))}}$, $n_{{EE}}=${ns11[1]}, $n_{{II}}=${ns22[1]}, $n_{{EI}}=${ns12[1]}, $n_{{IE}}=${ns21[1]}', fontsize = 8)
fig.axes[2].set_title(f'$\mu_E=10^{ {int(np.log10(mus1[2]))}}$, $\mu_I=10^{ {int(np.log10(mus2[2]))}}$, $n_{{EE}}=${ns11[2]}, $n_{{II}}=${ns22[2]}, $n_{{EI}}=${ns12[2]}, $n_{{IE}}=${ns21[2]}', fontsize = 8)

fig.supxlabel('Resolution parameter $\Delta$', fontsize=16)
fig.axes[0].minorticks_off()
fig.axes[2].minorticks_off()
fig.axes[0].legend(labels, loc='best', ncol=1)
fig.supylabel('Percolation strength $P_{\infty}$', fontsize=16)
fig.tight_layout()
